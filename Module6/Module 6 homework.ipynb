# %% [markdown]
# 09.08.20

# %% [markdown]
# # 1
# https://www.hackerrank.com/challenges/re-sub-regex-substitution/problem
# ![module6%20hw%20Q1%20solution.png](attachment:module6%20hw%20Q1%20solution.png)

# %% [markdown]
# # 2
# https://www.hackerrank.com/challenges/validating-named-email-addresses/problem
# ![module6%20hw%20Q2%20solution.png](attachment:module6%20hw%20Q2%20solution.png)
